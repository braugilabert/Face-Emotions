# %% [markdown]
# # Clasificador paisajes
# Para este ejercicio vas a crear un clasificador automático de paisajes. Los datos los encontrarás en el Classroom como `seg_train.zip` y `seg_test.zip`. Se pide:
# 1. Cargar las imágenes. Mira cómo están almacenados los datos. Tendrás que recorrer las carpetas, cargar las imágenes en memoria y etiquetarlas con los nombres de las carpetas. Realiza un reshape de cada imagen (comienza el ejercicio con 32x32, para ir más rápido en las ejecuciones).
# 2. Investiga las imágenes, comprueba con algunas muestras que has cargado bien los datos.
# 3. Normaliza
# 4. Diseña la arquitectura de la red. Recuerda que es un algoritmo de clasificación. Ojo con las dimensiones de la entrada
# 5. Reserva un 20% de los datos del entrenamiento para validar.
# 6. Representa el objeto history
# 7. Evalua el modelo con los datos de test
# 8. Representa algunos de los paisajes donde el modelo comete errores
# 9. Crea una matriz de confusión con los errores del modelo
#
# **NOTA apartado 1**: para el apartado 1 tendras que recorre las carpetas/imagenes con `os.listdir()`, e ir cargando todas las imagenes como arrays de numpy
#
# **NOTA apartado 4**: empieza con un par de capas Conv2D + MaxPooling2D con activación relu y después la fully connected layer. on softmax como ultima capa

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tensorflow import keras
import cv2
from skimage.io import imread
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       3 import matplotlib.pyplot as plt
#       4 import os
# ----> 5 from tensorflow import keras
#       6 import cv2
#       7 from skimage.io import imread
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
# !pip install tensorflow.python
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow.python (from versions: none)
# ERROR: No matching distribution found for tensorflow.python

# %%
class_names = ['angry','disgust','fear','happy','neutral','sad','surprise']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}
class_names_label
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
IMAGE_SIZE = (48,48)
TRAIN_PATH = os.getcwd() + '\\data\\train'
TEST_PATH = os.getcwd() + '\\data\\test'

# %%
def read_data(path, im_size):
    X = []
    Y = []

    for folder in os.listdir(path):
        label = class_names_label[folder]
        folder_path = os.path.join(path, folder)

    ##### CODE #####
    # Iterar sobre todo lo que haya en path
        for file in os.listdir(folder_path):
            
            # Leer la imagen a color y aplicarle el resize
            image_path = os.path.join(folder_path, file)
            image = imread(image_path)
            smallimage = cv2.resize(image, im_size)
            
            # Guardo en X
            X.append(smallimage)
            Y.append(label)

    return np.array(X), np.array(Y)
    

X_train, y_train = read_data(TRAIN_PATH, IMAGE_SIZE)
X_test, y_test = read_data(TEST_PATH, IMAGE_SIZE)

print(X_train.shape)
print(X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 25
#      20             Y.append(label)
#      22     return np.array(X), np.array(Y)
# ---> 25 X_train, y_train = read_data(TRAIN_PATH, IMAGE_SIZE)
#      26 X_test, y_test = read_data(TEST_PATH, IMAGE_SIZE)
#      28 print(X_train.shape)
#
# Cell In[6], line 15, in read_data(path, im_size)
#      11 for file in os.listdir(folder_path):
#      12
#      13     # Leer la imagen a color y aplicarle el resize
#      14     image_path = os.path.join(folder_path, file)
# ---> 15     image = imread(image_path)
#      16     smallimage = cv2.resize(image, im_size)
#      18     # Guardo en X
#
# NameError: name 'imread' is not defined

# %%
""" #SEGUNDO MODELO POR SI ACASO

from keras.applications.vgg16 import VGG16

base_model = VGG16(
        weights=None,
        include_top=False, 
        input_shape=IMG_SIZE + (3,)
    )

base_model.summary() """

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train, random_state=10)
X_test, y_test = shuffle(X_test, y_test, random_state=10)

# %%
print(X_train.min())
print(X_train.max())
X_train.shape
# Out:
# 0.0
# 1.0

# %%
model = keras.Sequential([
    keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(48,48)), # input_shape=(48,48,3)
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(32, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(6, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 30, 30, 64)        1792
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 32)        18464
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 1152)              0
#
#  dense_6 (Dense)             (None, 32)                36896
#
#  dense_7 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 57,350
# Trainable params: 57,350
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/20
# 88/88 [==============================] - 14s 151ms/step - loss: 1.2992 - accuracy: 0.4850 - val_loss: 1.1077 - val_accuracy: 0.5639
# Epoch 2/20
# 88/88 [==============================] - 14s 163ms/step - loss: 1.0200 - accuracy: 0.6075 - val_loss: 0.9963 - val_accuracy: 0.6181
# Epoch 3/20
# 88/88 [==============================] - 13s 151ms/step - loss: 0.9517 - accuracy: 0.6377 - val_loss: 1.0010 - val_accuracy: 0.6049
# Epoch 4/20
# 88/88 [==============================] - 14s 159ms/step - loss: 0.8772 - accuracy: 0.6713 - val_loss: 0.8887 - val_accuracy: 0.6755
# Epoch 5/20
# 88/88 [==============================] - 14s 160ms/step - loss: 0.8323 - accuracy: 0.6892 - val_loss: 0.8466 - val_accuracy: 0.6929
# Epoch 6/20
# 88/88 [==============================] - 14s 158ms/step - loss: 0.8134 - accuracy: 0.7019 - val_loss: 0.8541 - val_accuracy: 0.6758
# Epoch 7/20
# 88/88 [==============================] - 14s 164ms/step - loss: 0.7937 - accuracy: 0.7101 - val_loss: 0.8286 - val_accuracy: 0.6990
# Epoch 8/20
# 88/88 [==============================] - 14s 154ms/step - loss: 0.7489 - accuracy: 0.7255 - val_loss: 0.8022 - val_accuracy: 0.7036
# Epoch 9/20
# 88/88 [==============================] - 13s 145ms/step - loss: 0.7373 - accuracy: 0.7327 - val_loss: 0.7926 - val_accuracy: 0.7104
# Epoch 10/20
# 88/88 [==============================] - 13s 147ms/step - loss: 0.7104 - accuracy: 0.7451 - val_loss: 0.9075 - val_accuracy: 0.6641
# Epoch 11/20
# 88/88 [==============================] - 14s 158ms/step - loss: 0.6993 - accuracy: 0.7509 - val_loss: 0.7747 - val_accuracy: 0.7200
# Epoch 12/20
# 88/88 [==============================] - 14s 155ms/step - loss: 0.6720 - accuracy: 0.7585 - val_loss: 0.7482 - val_accuracy: 0.7257
# Epoch 13/20
# 88/88 [==============================] - 14s 154ms/step - loss: 0.6330 - accuracy: 0.7732 - val_loss: 0.7064 - val_accuracy: 0.7481
# Epoch 14/20
# 88/88 [==============================] - 13s 148ms/step - loss: 0.6305 - accuracy: 0.7783 - val_loss: 0.7161 - val_accuracy: 0.7510
# Epoch 15/20
# 88/88 [==============================] - 15s 173ms/step - loss: 0.5965 - accuracy: 0.7870 - val_loss: 0.7290 - val_accuracy: 0.7410
# Epoch 16/20
# 88/88 [==============================] - 12s 142ms/step - loss: 0.6015 - accuracy: 0.7890 - val_loss: 0.7015 - val_accuracy: 0.7449
# Epoch 17/20
# 88/88 [==============================] - 12s 132ms/step - loss: 0.5695 - accuracy: 0.7986 - val_loss: 0.6927 - val_accuracy: 0.7499
# Epoch 18/20
# 88/88 [==============================] - 14s 157ms/step - loss: 0.5672 - accuracy: 0.7964 - val_loss: 0.6623 - val_accuracy: 0.7620
# Epoch 19/20
# 88/88 [==============================] - 13s 148ms/step - loss: 0.5514 - accuracy: 0.8042 - val_loss: 0.6902 - val_accuracy: 0.7581
# Epoch 20/20
# 88/88 [==============================] - 13s 146ms/step - loss: 0.5339 - accuracy: 0.8072 - val_loss: 0.6640 - val_accuracy: 0.7670

# %%
df_hist = pd.DataFrame(history.history)
df_hist
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.299167  0.484992  1.107724      0.563947
# 1   1.020007  0.607464  0.996296      0.618098
# 2   0.951706  0.637748  1.000984      0.604916
# 3   0.877205  0.671328  0.888670      0.675454
# 4   0.832307  0.689231  0.846638      0.692911
# 5   0.813350  0.701879  0.854125      0.675810
# 6   0.793658  0.710074  0.828650      0.698967
# 7   0.748888  0.725483  0.802223      0.703598
# 8   0.737313  0.732698  0.792574      0.710367
# 9   0.710449  0.745079  0.907527      0.664054
# 10  0.699259  0.750868  0.774717      0.719986
# 11  0.672019  0.758529  0.748212      0.725686
# 12  0.632959  0.773225  0.706379      0.748130
# 13  0.630468  0.778302  0.716104      0.750980
# 14  0.596544  0.787031  0.728970      0.741005
# 15  0.601462  0.788991  0.701457      0.744923
# 16  0.569460  0.798611  0.692664      0.749911
# 17  0.567247  0.796384  0.662342      0.762024
# 18  0.551384  0.804222  0.690233      0.758105
# 19  0.533872  0.807161  0.664025      0.767011

# %%
results = model.evaluate(X_test, y_test)
results
# Out:
# 94/94 [==============================] - 1s 13ms/step - loss: 0.6494 - accuracy: 0.7567
# [0.649420440196991, 0.7566666603088379]

# %%
y_pred = model.predict(X_test)
y_pred.round(2)
# Out:
# array([[0.9 , 0.  , 0.03, 0.  , 0.07, 0.  ],
#        [0.01, 0.19, 0.03, 0.75, 0.01, 0.01],
#        [0.08, 0.  , 0.79, 0.  , 0.12, 0.  ],
#        ...,
#        [0.19, 0.07, 0.66, 0.02, 0.04, 0.01],
#        [0.  , 0.  , 0.  , 0.  , 0.  , 1.  ],
#        [0.25, 0.02, 0.58, 0.01, 0.13, 0.  ]], dtype=float32)

# %%
pred_labels = np.argmax(y_pred, axis=1)
pred_labels
# Out:
# array([0, 3, 2, ..., 2, 5, 2], dtype=int64)

# %%
label_pred = [class_names[pred] for pred in pred_labels]
label_pred
# Out:
# ['mountain',
#  'buildings',
#  'glacier',
#  'sea',
#  'forest',
#  'mountain',
#  'glacier',
#  'glacier',
#  'sea',
#  'street',
#  'buildings',
#  'sea',
#  'sea',
#  'buildings',
#  'street',
#  'sea',
#  'glacier',
#  'mountain',
#  'glacier',
#  'buildings',
#  'buildings',
#  'glacier',
#  'buildings',
#  'glacier',
#  'buildings',
#  'glacier',
#  'sea',
#  'buildings',
#  'forest',
#  'forest',
#  'mountain',
#  'sea',
#  'glacier',
#  'glacier',
#  'sea',
#  'mountain',
#  'street',
#  'mountain',
#  'sea',
#  'forest',
#  'forest',
#  'buildings',
#  'glacier',
#  'street',
#  'glacier',
#  'mountain',
#  'buildings',
#  'mountain',
#  'glacier',
#  'glacier',
#  'forest',
#  'street',
#  'sea',
#  'glacier',
#  'glacier',
#  'glacier',
#  'forest',
#  'sea',
#  'glacier',
#  'forest',
#  'mountain',
#  'glacier',
#  'glacier',
#  'forest',
#  'buildings',
#  'buildings',
#  'sea',
#  'glacier',
#  'mountain',
#  'sea',
#  'forest',
#  'mountain',
#  'mountain',
#  'sea',
#  'glacier',
#  'street',
#  'street',
#  'buildings',
#  'sea',
#  'forest',
#  'glacier',
#  'sea',
#  'mountain',
#  'street',
#  'glacier',
#  'street',
#  'glacier',
#  'glacier',
#  'mountain',
#  'sea',
#  'sea',
#  'street',
#  'mountain',
#  'buildings',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'glacier',
#  'glacier',
#  'mountain',
#  'forest',
#  'glacier',
#  'forest',
#  'forest',
#  'sea',
#  'glacier',
#  'sea',
#  'glacier',
#  'mountain',
#  'mountain',
#  'forest',
#  'buildings',
#  'street',
#  'glacier',
#  'sea',
#  'forest',
#  'glacier',
#  'sea',
#  'sea',
#  'glacier',
#  'sea',
#  'glacier',
#  'sea',
#  'mountain',
#  'sea',
#  'glacier',
#  'street',
#  'glacier',
#  'sea',
#  'street',
#  'forest',
#  'street',
#  'glacier',
#  'glacier',
#  'mountain',
#  'forest',
#  'buildings',
#  'glacier',
#  'sea',
#  'sea',
#  'mountain',
#  'street',
#  'buildings',
#  'forest',
#  'glacier',
#  'mountain',
#  'sea',
#  'buildings',
#  'buildings',
#  'forest',
#  'glacier',
#  'mountain',
#  'mountain',
#  'buildings',
#  'mountain',
#  'glacier',
#  'forest',
#  'mountain',
#  'buildings',
#  'glacier',
#  'forest',
#  'sea',
#  'buildings',
#  'buildings',
#  'sea',
#  'buildings',
#  'street',
#  'street',
#  'buildings',
#  'sea',
#  'sea',
#  'forest',
#  'street',
#  'buildings',
#  'sea',
#  'glacier',
#  'glacier',
#  'buildings',
#  'street',
#  'mountain',
#  'sea',
#  'forest',
#  'glacier',
#  'sea',
#  'glacier',
#  'street',
#  'street',
#  'forest',
#  'forest',
#  'mountain',
#  'forest',
#  'buildings',
#  'glacier',
#  'sea',
#  'sea',
#  'glacier',
#  'buildings',
#  'glacier',
#  'sea',
#  'glacier',
#  'glacier',
#  'mountain',
#  'glacier',
#  'buildings',
#  'forest',
#  'forest',
#  'buildings',
#  'buildings',
#  'buildings',
#  'forest',
#  'street',
#  'sea',
#  'mountain',
#  'forest',
#  'glacier',
#  'buildings',
#  'sea',
#  'forest',
#  'forest',
#  'forest',
#  'mountain',
#  'street',
#  'street',
#  'glacier',
#  'mountain',
#  'glacier',
#  'sea',
#  'buildings',
#  'buildings',
#  'sea',
#  'glacier',
#  'buildings',
#  'sea',
#  'forest',
#  'glacier',
#  'street',
#  'forest',
#  'buildings',
#  'glacier',
#  'sea',
#  'buildings',
#  'forest',
#  'glacier',
#  'sea',
#  'sea',
#  'buildings',
#  'glacier',
#  'mountain',
#  'mountain',
#  'sea',
#  'forest',
#  'glacier',
#  'buildings',
#  'glacier',
#  'forest',
#  'forest',
#  'street',
#  'street',
#  'forest',
#  'glacier',
#  'forest',
#  'sea',
#  'glacier',
#  'buildings',
#  'mountain',
#  'buildings',
#  'mountain',
#  'buildings',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'glacier',
#  'buildings',
#  'street',
#  'forest',
#  'mountain',
#  'glacier',
#  'street',
#  'glacier',
#  'buildings',
#  'forest',
#  'sea',
#  'street',
#  'sea',
#  'buildings',
#  'buildings',
#  'glacier',
#  'sea',
#  'sea',
#  'street',
#  'buildings',
#  'buildings',
#  'forest',
#  'mountain',
#  'mountain',
#  'mountain',
#  'mountain',
#  'street',
#  'sea',
#  'sea',
#  'street',
#  'mountain',
#  'street',
#  'forest',
#  'buildings',
#  'forest',
#  'glacier',
#  'glacier',
#  'glacier',
#  'street',
#  'sea',
#  'buildings',
#  'street',
#  'buildings',
#  'forest',
#  'street',
#  'mountain',
#  'buildings',
#  'sea',
#  'forest',
#  'glacier',
#  'mountain',
#  'glacier',
#  'mountain',
#  'forest',
#  'mountain',
#  'street',
#  'glacier',
#  'street',
#  'glacier',
#  'mountain',
#  'forest',
#  'mountain',
#  'glacier',
#  'sea',
#  'buildings',
#  'sea',
#  'street',
#  'mountain',
#  'street',
#  'forest',
#  'mountain',
#  'sea',
#  'sea',
#  'glacier',
#  'sea',
#  'mountain',
#  'buildings',
#  'mountain',
#  'mountain',
#  'glacier',
#  'forest',
#  'forest',
#  'forest',
#  'buildings',
#  'forest',
#  'sea',
#  'street',
#  'forest',
#  'forest',
#  'street',
#  'forest',
#  'buildings',
#  'glacier',
#  'buildings',
#  'street',
#  'sea',
#  'forest',
#  'sea',
#  'glacier',
#  'mountain',
#  'street',
#  'sea',
#  'forest',
#  'mountain',
#  'sea',
#  'glacier',
#  'street',
#  'street',
#  'buildings',
#  'glacier',
#  'sea',
#  'sea',
#  'sea',
#  'buildings',
#  'glacier',
#  'street',
#  'street',
#  'buildings',
#  'street',
#  'glacier',
#  'street',
#  'sea',
#  'street',
#  'glacier',
#  'street',
#  'sea',
#  'forest',
#  'glacier',
#  'street',
#  'sea',
#  'glacier',
#  'street',
#  'street',
#  'glacier',
#  'glacier',
#  'glacier',
#  'glacier',
#  'sea',
#  'glacier',
#  'mountain',
#  'forest',
#  'forest',
#  'mountain',
#  'sea',
#  'forest',
#  'forest',
#  'buildings',
#  'glacier',
#  'glacier',
#  'forest',
#  'buildings',
#  'glacier',
#  'street',
#  'forest',
#  'buildings',
#  'buildings',
#  'buildings',
#  'sea',
#  'buildings',
#  'sea',
#  'sea',
#  'buildings',
#  'forest',
#  'mountain',
#  'mountain',
#  'sea',
#  'mountain',
#  'buildings',
#  'forest',
#  'glacier',
#  'mountain',
#  'buildings',
#  'sea',
#  'sea',
#  'sea',
#  'glacier',
#  'buildings',
#  'glacier',
#  'glacier',
#  'forest',
#  'mountain',
#  'glacier',
#  'street',
#  'street',
#  'sea',
#  'mountain',
#  'forest',
#  'glacier',
#  'forest',
#  'glacier',
#  'glacier',
#  'street',
#  'glacier',
#  'street',
#  'mountain',
#  'mountain',
#  'sea',
#  'mountain',
#  'sea',
#  'street',
#  'mountain',
#  'buildings',
#  'sea',
#  'street',
#  'mountain',
#  'street',
#  'glacier',
#  'buildings',
#  'street',
#  'glacier',
#  'street',
#  'buildings',
#  'glacier',
#  'glacier',
#  'street',
#  'sea',
#  'mountain',
#  'forest',
#  'sea',
#  'glacier',
#  'glacier',
#  'street',
#  'street',
#  'mountain',
#  'forest',
#  'sea',
#  'mountain',
#  'sea',
#  'glacier',
#  'forest',
#  'street',
#  'forest',
#  'mountain',
#  'street',
#  'glacier',
#  'buildings',
#  'street',
#  'mountain',
#  'buildings',
#  'street',
#  'glacier',
#  'mountain',
#  'buildings',
#  'sea',
#  'street',
#  'glacier',
#  'forest',
#  'mountain',
#  'street',
#  'mountain',
#  'sea',
#  'sea',
#  'buildings',
#  'forest',
#  'sea',
#  'buildings',
#  'sea',
#  'sea',
#  'mountain',
#  'buildings',
#  'sea',
#  'forest',
#  'forest',
#  'mountain',
#  'street',
#  'sea',
#  'mountain',
#  'glacier',
#  'mountain',
#  'buildings',
#  'sea',
#  'glacier',
#  'buildings',
#  'mountain',
#  'buildings',
#  'glacier',
#  'sea',
#  'glacier',
#  'mountain',
#  'glacier',
#  'forest',
#  'forest',
#  'sea',
#  'mountain',
#  'buildings',
#  'forest',
#  'mountain',
#  'forest',
#  'buildings',
#  'buildings',
#  'mountain',
#  'mountain',
#  'buildings',
#  'street',
#  'street',
#  'forest',
#  'buildings',
#  'sea',
#  'forest',
#  'buildings',
#  'mountain',
#  'sea',
#  'mountain',
#  'forest',
#  'mountain',
#  'buildings',
#  'glacier',
#  'mountain',
#  'glacier',
#  'street',
#  'sea',
#  'buildings',
#  'buildings',
#  'glacier',
#  'mountain',
#  'sea',
#  'buildings',
#  'street',
#  'buildings',
#  'sea',
#  'forest',
#  'sea',
#  'mountain',
#  'sea',
#  'sea',
#  'street',
#  'buildings',
#  'street',
#  'glacier',
#  'street',
#  'sea',
#  'sea',
#  'forest',
#  'glacier',
#  'mountain',
#  'mountain',
#  'forest',
#  'sea',
#  'forest',
#  'buildings',
#  'mountain',
#  'sea',
#  'mountain',
#  'street',
#  'mountain',
#  'buildings',
#  'sea',
#  'mountain',
#  'glacier',
#  'buildings',
#  'sea',
#  'buildings',
#  'glacier',
#  'mountain',
#  'street',
#  'glacier',
#  'street',
#  'mountain',
#  'street',
#  'sea',
#  'glacier',
#  'forest',
#  'forest',
#  'sea',
#  'glacier',
#  'street',
#  'forest',
#  'buildings',
#  'glacier',
#  'mountain',
#  'mountain',
#  'street',
#  'mountain',
#  'mountain',
#  'mountain',
#  'glacier',
#  'buildings',
#  'sea',
#  'street',
#  'glacier',
#  'glacier',
#  'glacier',
#  'sea',
#  'glacier',
#  'street',
#  'sea',
#  'buildings',
#  'buildings',
#  'glacier',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'glacier',
#  'glacier',
#  'forest',
#  'mountain',
#  'mountain',
#  'forest',
#  'sea',
#  'buildings',
#  'glacier',
#  'mountain',
#  'street',
#  'mountain',
#  'glacier',
#  'glacier',
#  'street',
#  'forest',
#  'street',
#  'mountain',
#  'buildings',
#  'mountain',
#  'forest',
#  'glacier',
#  'forest',
#  'buildings',
#  'sea',
#  'street',
#  'sea',
#  'forest',
#  'mountain',
#  'buildings',
#  'glacier',
#  'forest',
#  'street',
#  'street',
#  'glacier',
#  'street',
#  'sea',
#  'forest',
#  'glacier',
#  'sea',
#  'sea',
#  'sea',
#  'sea',
#  'forest',
#  'forest',
#  'glacier',
#  'glacier',
#  'buildings',
#  'sea',
#  'sea',
#  'street',
#  'mountain',
#  'sea',
#  'street',
#  'sea',
#  'mountain',
#  'mountain',
#  'buildings',
#  'sea',
#  'glacier',
#  'buildings',
#  'street',
#  'glacier',
#  'glacier',
#  'mountain',
#  'street',
#  'street',
#  'buildings',
#  'buildings',
#  'street',
#  'glacier',
#  'mountain',
#  'sea',
#  'glacier',
#  'forest',
#  'forest',
#  'sea',
#  'sea',
#  'buildings',
#  'sea',
#  'forest',
#  'sea',
#  'glacier',
#  'glacier',
#  'street',
#  'sea',
#  'forest',
#  'forest',
#  'sea',
#  'forest',
#  'glacier',
#  'glacier',
#  'sea',
#  'glacier',
#  'sea',
#  'glacier',
#  'sea',
#  'sea',
#  'forest',
#  'forest',
#  'street',
#  'forest',
#  'sea',
#  'forest',
#  'sea',
#  'glacier',
#  'glacier',
#  'glacier',
#  'mountain',
#  'mountain',
#  'forest',
#  'street',
#  'glacier',
#  'forest',
#  'forest',
#  'glacier',
#  'mountain',
#  'glacier',
#  'sea',
#  'buildings',
#  'sea',
#  'glacier',
#  'mountain',
#  'street',
#  'glacier',
#  'forest',
#  'mountain',
#  'buildings',
#  'mountain',
#  'sea',
#  'mountain',
#  'street',
#  'buildings',
#  'street',
#  'sea',
#  'sea',
#  'street',
#  'mountain',
#  'mountain',
#  'street',
#  'buildings',
#  'buildings',
#  'glacier',
#  'glacier',
#  'buildings',
#  'buildings',
#  'street',
#  'glacier',
#  'street',
#  'street',
#  'buildings',
#  'street',
#  'sea',
#  'mountain',
#  'glacier',
#  'street',
#  'buildings',
#  'mountain',
#  'forest',
#  'sea',
#  'glacier',
#  'glacier',
#  'mountain',
#  'sea',
#  'mountain',
#  'street',
#  'mountain',
#  'mountain',
#  'glacier',
#  'sea',
#  'street',
#  'mountain',
#  'buildings',
#  'buildings',
#  'street',
#  'mountain',
#  'street',
#  'street',
#  'sea',
#  'glacier',
#  'buildings',
#  'sea',
#  'forest',
#  'forest',
#  'buildings',
#  'glacier',
#  'sea',
#  'sea',
#  'mountain',
#  'street',
#  'forest',
#  'sea',
#  'street',
#  'buildings',
#  'street',
#  'sea',
#  'buildings',
#  'sea',
#  'buildings',
#  'street',
#  'mountain',
#  'forest',
#  'buildings',
#  'glacier',
#  'sea',
#  'buildings',
#  'street',
#  'sea',
#  'buildings',
#  'mountain',
#  'buildings',
#  'forest',
#  'sea',
#  'mountain',
#  'glacier',
#  'forest',
#  'mountain',
#  'buildings',
#  'street',
#  'glacier',
#  'street',
#  'sea',
#  'buildings',
#  'mountain',
#  'sea',
#  'glacier',
#  'buildings',
#  'street',
#  'street',
#  'sea',
#  'forest',
#  'mountain',
#  'glacier',
#  'forest',
#  'glacier',
#  'forest',
#  'sea',
#  'forest',
#  'glacier',
#  'sea',
#  'forest',
#  'forest',
#  'buildings',
#  'mountain',
#  'forest',
#  'sea',
#  'sea',
#  'buildings',
#  'forest',
#  'mountain',
#  'street',
#  'buildings',
#  'forest',
#  'mountain',
#  'street',
#  'sea',
#  'sea',
#  'glacier',
#  'sea',
#  'mountain',
#  'forest',
#  'street',
#  'sea',
#  'sea',
#  'forest',
#  'mountain',
#  'mountain',
#  'glacier',
#  'forest',
#  'glacier',
#  'forest',
#  'forest',
#  'buildings',
#  'sea',
#  'glacier',
#  'glacier',
#  'mountain',
#  'sea',
#  'buildings',
#  'street',
#  'street',
#  'sea',
#  'sea',
#  'mountain',
#  'sea',
#  'mountain',
#  'sea',
#  'glacier',
#  'street',
#  'sea',
#  'street',
#  'street',
#  'buildings',
#  'mountain',
#  'street',
#  'mountain',
#  'sea',
#  'forest',
#  'glacier',
#  'mountain',
#  'sea',
#  'mountain',
#  'sea',
#  'street',
#  'glacier',
#  'forest',
#  'mountain',
#  'mountain',
#  'glacier',
#  'mountain',
#  'glacier',
#  'street',
#  'buildings',
#  'street',
#  'sea',
#  'buildings',
#  'mountain',
#  'street',
#  'sea',
#  'sea',
#  'mountain',
#  'glacier',
#  'buildings',
#  'glacier',
#  'forest',
#  'street',
#  'street',
#  'forest',
#  'buildings',
#  'buildings',
#  'forest',
#  'sea',
#  'buildings',
#  ...]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

c_mat = confusion_matrix(y_test, pred_labels, normalize='true')
sns.heatmap(c_mat, annot=True, xticklabels=class_names, yticklabels=class_names)
# Out:
# <AxesSubplot:>
